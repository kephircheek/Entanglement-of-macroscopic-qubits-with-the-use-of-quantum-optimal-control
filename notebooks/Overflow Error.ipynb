# %%
import qutip

def dot(ais, bis):
    """
    Dot product
    """
    return sum(ai*bi for ai, bi in zip(ais, bis))
fock_trunc = 20
n_modes = len(fs)
a = qutip.destroy(fock_trunc)
ad = a.dag()
n = qutip.num(fock_trunc)
mode_fields = [tensor_out(a + ad, i) for i in range(n_modes)]
mode_ns = [tensor_out(n, i) for i in range(n_modes)]
linear_part = dot(mode_fields, mode_ns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       7     return sum(ai*bi for ai, bi in zip(ais, bis))
#       8 fock_trunc = 20
# ----> 9 n_modes = len(fs)
#      10 a = qutip.destroy(fock_trunc)
#      11 ad = a.dag()
#
# NameError: name 'fs' is not defined
